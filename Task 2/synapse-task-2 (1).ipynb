# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv("/kaggle/input/gesknkajh/GE_2024_Results (1).csv")
df
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8901  8899                West Bengal                   Uluberia
# 8902  8900                West Bengal                   Uluberia
# 8903  8904  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904  8901                West Bengal                   Uluberia
# 8905  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# ...

# %%
df.shape
# Out:
# (8906, 10)

# %%
df.head(20)
# Out:
#     ID                      State               Constituency  \
# 0    1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1    2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2    3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5    5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6    6  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7    7  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8    8  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10   9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11  10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12  11  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13  12  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...

# %%
newdf=df.drop("ID",axis=1)
newdf
# Out:
#                           State               Constituency  \
# 0     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...                         ...                        ...
# 8901                West Bengal                   Uluberia
# 8902                West Bengal                   Uluberia
# 8903  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904                West Bengal                   Uluberia
# 8905                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# ...

# %%
newdf.dropna(axis=0,how='any')
newdf.dropna(axis=1,how="any")
newdf.reset_index(inplace=True)

# %%
newdf.sort_values(by="EVM Votes",ascending=False)
# Out:
#       index                      State               Constituency  \
# 1593   1593                    Gujarat                Gandhinagar
# 3661   3661                Maharashtra                   Baramati
# 3146   3146             Madhya Pradesh                   BALAGHAT
# 881     881                      Bihar                 Kishanganj
# 1564   1564                    Gujarat                  Bhavnagar
# ...     ...                        ...                        ...
# 1740   1740                    Gujarat                      Surat
# 3         3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9         9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 16       16  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8903   8903  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#                                            Candidate  \
# 1593                                       AMIT SHAH
# 3661                  PRIYADARSHANI NANDKUMAR KOKARE
# ...

# %%
print(newdf[["State",'Total Votes']])
# Out:
#                           State  Total Votes
# 0     Andaman & Nicobar Islands     102436.0
# 1     Andaman & Nicobar Islands      78040.0
# 2     Andaman & Nicobar Islands       8254.0
# 3     Andaman & Nicobar Islands          NaN
# 4     Andaman & Nicobar Islands       6017.0
# ...                         ...          ...
# 8901                West Bengal       2107.0
# 8902                West Bengal       2000.0
# 8903  Andaman & Nicobar Islands          NaN
# 8904                West Bengal       1572.0
# 8905                West Bengal      11318.0
#
# [8906 rows x 2 columns]

# %%
print(newdf[["% of Votes"]])
# Out:
#      % of Votes
# 0         50.58
# 1         38.54
# 2          4.08
# 3           NaN
# 4          2.97
# ...         ...
# 8901       0.15
# 8902       0.14
# 8903        NaN
# 8904       0.11
# 8905       0.81
#
# [8906 rows x 1 columns]

# %%
newdf.sort_values(by="Total Votes",ascending=False).head(5)
# Out:
#       index           State     Constituency              Candidate  \
# 538     538           Assam           Dhubri        RAKIBUL HUSSAIN
# 3292   3292  Madhya Pradesh           INDORE        SHANKAR LALWANI
# 3525   3525  Madhya Pradesh          VIDISHA  SHIVRAJ SINGH CHOUHAN
# 2486   2486       Karnataka  Bangalore Rural       DR C N MANJUNATH
# 1390   1390    Chhattisgarh           RAIPUR      BRIJMOHAN AGRAWAL
#
#                          Party EVM Votes Postal Votes  Total Votes % of Votes  \
# 538   Indian National Congress   1468549         3336    1471885.0      59.99
# 3292    Bharatiya Janata Party   1223746         3005    1226751.0      78.54
# 3525    Bharatiya Janata Party   1111556         4904    1116460.0       76.7
# 2486    Bharatiya Janata Party   1075553         3449    1079002.0      56.21
# 1390    Bharatiya Janata Party   1047447         2904    1050351.0      66.19
#
#      Result
# 538     Won
# 3292    Won
# 3525    Won
# 2486    Won
# 1390    Won

# %%
index_place=newdf[newdf['Result']=='Won'].index
newdf.drop(index_place,axis=0)
newdf.sort_values(by='% of Votes',ascending=False).head(10)
# Out:
#       index              State     Constituency  \
# 3113   3113             Kerala         Vadakara
# 6998   6998          Telangana      Mahabubabad
# 7487   7487      Uttar Pradesh          Baghpat
# 5873   5873         Tamil Nadu  CHENNAI CENTRAL
# 6081   6081         Tamil Nadu         DINDIGUL
# 2122   2122  Jammu and Kashmir         SRINAGAR
# 6443   6443         Tamil Nadu            SALEM
# 6491   6491         Tamil Nadu    SRIPERUMBUDUR
# 5350   5350             Punjab       Hoshiarpur
# 5230   5230             Punjab         Bathinda
#
#                              Candidate                             Party  \
# 3113                  PRAPHUL KRISHNAN            Bharatiya Janata Party
# 6998  PROFESSOR. AZMEERA SEETARAM NAIK            Bharatiya Janata Party
# 7487                    PRAVEEN BANSAL               Bahujan Samaj Party
# 5873                  B. PARTHASARATHY  Desiya Murpokku Dravida Kazhagam
# ...

# %%
data=newdf.sort_values(by='Total Votes',ascending=False).head(5)
list=[]
list.append(data)
list
candidate=['PRAPHUL KRISHNAN','PROFESSOR. AZMEERA SEETARAM NAIK','PRAVEEN BANSAL','B. PARTHASARATHY','B. PARTHASARATHY']

plt.pie(list,labels=candidate)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33/2731218602.py in ?()
#       3 list.append(data)
#       4 list
#       5 candidate=['PRAPHUL KRISHNAN','PROFESSOR. AZMEERA SEETARAM NAIK','PRAVEEN BANSAL','B. PARTHASARATHY','B. PARTHASARATHY']
#       6
# ----> 7 plt.pie(list,labels=candidate)
#
# /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py in ?(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2795         pctdistance=0.6, shadow=False, labeldistance=1.1,
#    2796         startangle=0, radius=1, counterclock=True, wedgeprops=None,
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
# ...

# %%
df["Postal Votes"] = df["Postal Votes"].replace("-", '0')

#Converting object to numeric datatype
df["Postal Votes"] = pd.to_numeric(df["Postal Votes"])

#ENTIRE GRAPH
df.loc[(df["State"] == "Karnataka") & (df["Party"] != "None of the Above")].groupby("Party")["Postal Votes"].sum().sort_values(ascending=False).plot(kind='bar', title='Postal Votes by Party in Karnataka', figsize=(15, 10), xlabel="Party", ylabel="Postal Votes")
# Out:
# <Axes: title={'center': 'Postal Votes by Party in Karnataka'}, xlabel='Party', ylabel='Postal Votes'>
